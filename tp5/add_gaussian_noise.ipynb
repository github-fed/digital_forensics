# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Load the image and convert to grayscale (optional, use 'RGB' for color images)
image = Image.open('sherlock.jpg').convert('RGB')
image_array = np.array(image)

# Define Gaussian noise parameters
mean = 0        # Mean of the Gaussian noise
std_dev = 40    # Standard deviation of the noise

# Generate Gaussian noise
gaussian_noise = np.random.normal(mean, std_dev, image_array.shape)

# Add the Gaussian noise to the image
noisy_image_array = image_array + gaussian_noise

# Clip values to be in the range [0, 255]
noisy_image_array = np.clip(noisy_image_array, 0, 255)

# Convert the noisy array back to an image
noisy_image = Image.fromarray(noisy_image_array.astype(np.uint8))

noisy_image.save('noisy_sherlock40.jpg')

# Display the original and noisy images
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')

plt.subplot(1, 2, 2)
plt.title("Noisy Image")
plt.imshow(noisy_image, cmap='gray')
plt.show()

# %%
from PIL import Image

# Load the image
image = Image.open('sherlock_compressed.jpg')

# Apply JPEG compression by saving with a specific quality level (e.g., 20)
compression_quality = 20  # Set quality between 1 (lowest) to 95 (highest)
compressed_image_path = 'sherlock_compressed_20.jpg'

# Save the image with compression
image.save(compressed_image_path, 'JPEG', quality=compression_quality)

print(f"Image saved with JPEG compression at quality {compression_quality}.")
# Out:
# Image saved with JPEG compression at quality 20.
